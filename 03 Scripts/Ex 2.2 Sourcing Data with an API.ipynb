# %% [markdown]
# # Ex 2.2 Sourcing Data with an API

# %% [markdown]
# ## Part 2: Gather and merge the data

# %% [markdown]
# ### 4. Import libraries and data

# %%
import pandas as pd 
import numpy as np
import os 
import requests
import json
from datetime import datetime

# %%
import os
os.getcwd()
# Out:
# '/Users/andymiller/Desktop/CareerFoundry Data Analytics/3. Data Visualisation with Python/2. Citi Bike/03 Scripts'

# %%
# Create a path
folderpath = r"/Users/andymiller/Desktop/CareerFoundry Data Analytics/3. Data Visualisation with Python/2. Citi Bike/02 Data/Original Data"

# %%
filepaths  = [os.path.join(folderpath, name) for name in os.listdir(folderpath)]

# %%
filepaths
# Out:
# ['/Users/andymiller/Desktop/CareerFoundry Data Analytics/3. Data Visualisation with Python/2. Citi Bike/02 Data/Original Data/202208-citibike-tripdata_3.csv',
#  '/Users/andymiller/Desktop/CareerFoundry Data Analytics/3. Data Visualisation with Python/2. Citi Bike/02 Data/Original Data/202207-citibike-tripdata_2.csv',
#  '/Users/andymiller/Desktop/CareerFoundry Data Analytics/3. Data Visualisation with Python/2. Citi Bike/02 Data/Original Data/202207-citibike-tripdata_3.csv',
#  '/Users/andymiller/Desktop/CareerFoundry Data Analytics/3. Data Visualisation with Python/2. Citi Bike/02 Data/Original Data/202208-citibike-tripdata_2.csv',
#  '/Users/andymiller/Desktop/CareerFoundry Data Analytics/3. Data Visualisation with Python/2. Citi Bike/02 Data/Original Data/202207-citibike-tripdata_1.csv',
#  '/Users/andymiller/Desktop/CareerFoundry Data Analytics/3. Data Visualisation with Python/2. Citi Bike/02 Data/Original Data/202208-citibike-tripdata_1.csv',
# ...

# %%
# Read and concatenate all files simultaneously

df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index = True)
# Out:
# /var/folders/w2/ktpt6z_d1353vv2y_fgqj5cm0000gn/T/ipykernel_52991/1585634694.py:3: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index = True)
# /var/folders/w2/ktpt6z_d1353vv2y_fgqj5cm0000gn/T/ipykernel_52991/1585634694.py:3: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index = True)
# /var/folders/w2/ktpt6z_d1353vv2y_fgqj5cm0000gn/T/ipykernel_52991/1585634694.py:3: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index = True)
# /var/folders/w2/ktpt6z_d1353vv2y_fgqj5cm0000gn/T/ipykernel_52991/1585634694.py:3: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
for f in filepaths:
    print(f)
# Out:
# /Users/andymiller/Desktop/CareerFoundry Data Analytics/3. Data Visualisation with Python/2. Citi Bike/02 Data/Original Data/202208-citibike-tripdata_3.csv
# /Users/andymiller/Desktop/CareerFoundry Data Analytics/3. Data Visualisation with Python/2. Citi Bike/02 Data/Original Data/202207-citibike-tripdata_2.csv
# /Users/andymiller/Desktop/CareerFoundry Data Analytics/3. Data Visualisation with Python/2. Citi Bike/02 Data/Original Data/202207-citibike-tripdata_3.csv
# /Users/andymiller/Desktop/CareerFoundry Data Analytics/3. Data Visualisation with Python/2. Citi Bike/02 Data/Original Data/202208-citibike-tripdata_2.csv
# /Users/andymiller/Desktop/CareerFoundry Data Analytics/3. Data Visualisation with Python/2. Citi Bike/02 Data/Original Data/202207-citibike-tripdata_1.csv
# /Users/andymiller/Desktop/CareerFoundry Data Analytics/3. Data Visualisation with Python/2. Citi Bike/02 Data/Original Data/202208-citibike-tripdata_1.csv
# ...

# %%
filepaths = [os.path.join(folderpath, name) for name in os.listdir(folderpath) if name.endswith(".csv")]

# %%
# Read and concatenate all files simultaneously

df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index = True)
# Out:
# /var/folders/w2/ktpt6z_d1353vv2y_fgqj5cm0000gn/T/ipykernel_52991/1585634694.py:3: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index = True)
# /var/folders/w2/ktpt6z_d1353vv2y_fgqj5cm0000gn/T/ipykernel_52991/1585634694.py:3: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index = True)
# /var/folders/w2/ktpt6z_d1353vv2y_fgqj5cm0000gn/T/ipykernel_52991/1585634694.py:3: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat((pd.read_csv(f) for f in filepaths), ignore_index = True)
# /var/folders/w2/ktpt6z_d1353vv2y_fgqj5cm0000gn/T/ipykernel_52991/1585634694.py:3: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
df.shape
# Out:
# (29838806, 13)

# %%
df.head()
# Out:
#             ride_id  rideable_type               started_at  \
# 0  9D0DC440CB40CF8E  electric_bike  2022-08-27 13:56:47.728
# 1  2214991DFBE5C4D7  electric_bike  2022-08-20 10:37:02.756
# 2  20C5D469563B6337   classic_bike  2022-08-31 18:55:03.051
# 3  3E8791885BC189D1   classic_bike  2022-08-02 08:05:00.250
# 4  8DBCBF98885106CB  electric_bike  2022-08-25 15:44:48.386
#
#                   ended_at        start_station_name start_station_id  \
# 0  2022-08-27 14:02:56.651  Flatbush Ave & Ocean Ave          3704.04
# 1  2022-08-20 10:45:56.631    Forsyth St\t& Grand St          5382.07
# 2  2022-08-31 19:03:37.344    Perry St & Bleecker St          5922.07
# 3  2022-08-02 08:16:52.063       FDR Drive & E 35 St          6230.04
# 4  2022-08-25 15:55:39.691           E 40 St & 5 Ave          6474.11
#
#                     end_station_name end_station_id  start_lat  start_lng  \
# 0          3 St & Prospect Park West        3865.05  40.663657 -73.963014
# ...

# %%
# Rename started_at and ended_at time for clarity

df.rename(columns = {'started_at' : 'start_time','ended_at' : 'end_time'}, inplace = True)

# %%
df.head()
# Out:
#             ride_id  rideable_type               start_time  \
# 0  9D0DC440CB40CF8E  electric_bike  2022-08-27 13:56:47.728
# 1  2214991DFBE5C4D7  electric_bike  2022-08-20 10:37:02.756
# 2  20C5D469563B6337   classic_bike  2022-08-31 18:55:03.051
# 3  3E8791885BC189D1   classic_bike  2022-08-02 08:05:00.250
# 4  8DBCBF98885106CB  electric_bike  2022-08-25 15:44:48.386
#
#                   end_time        start_station_name start_station_id  \
# 0  2022-08-27 14:02:56.651  Flatbush Ave & Ocean Ave          3704.04
# 1  2022-08-20 10:45:56.631    Forsyth St\t& Grand St          5382.07
# 2  2022-08-31 19:03:37.344    Perry St & Bleecker St          5922.07
# 3  2022-08-02 08:16:52.063       FDR Drive & E 35 St          6230.04
# 4  2022-08-25 15:55:39.691           E 40 St & 5 Ave          6474.11
#
#                     end_station_name end_station_id  start_lat  start_lng  \
# 0          3 St & Prospect Park West        3865.05  40.663657 -73.963014
# ...

# %% [markdown]
# ### 5. Explanation of code from point 4
#
# The code used for point 4 works as follows:
#
# The folderpath was defined, then a list called filepaths was created that joined all of the directory paths and file names of the csv files in the folder that the folderpath points to. Each of files from the list that is of type .csv are then read and a dataframe is created to hold the data from each file which is concatenated (vertically). This results in a dataframe with over 29 million rows and 13 columns.

# %% [markdown]
# ### 6. Token obtained

# %% [markdown]
# ### 7. Obtain weather data

# %%
# Define your NOAA token - type yours in here! 

Token = 'RftqahyWxDfBEUNccuhRIdUlKXQGlizE'
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
# Get the API 

r = requests.get('https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TAVG&limit=1000&stationid=GHCND:USW00014732&startdate=2022-01-01&enddate=2022-12-31', headers={'token':Token})

# %%
# Load the api response as a json

d = json.loads(r.text)

# %%
d
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 365, 'limit': 1000}},
#  'results': [{'date': '2022-01-01T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 116},
#   {'date': '2022-01-02T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 114},
#   {'date': '2022-01-03T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 14},
#   {'date': '2022-01-04T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': -27},
#   {'date': '2022-01-05T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 32},
#   {'date': '2022-01-06T00:00:00',
#    'datatype': 'TAVG',
#    'station': 'GHCND:USW00014732',
#    'attributes': 'H,,S,',
#    'value': 49},
#   {'date': '2022-01-07T00:00:00',
# ...

# %%
# Secure all items in the response that correspond to TAVG

avg_temps = [item for item in d['results'] if item['datatype']=='TAVG']

# %%
# Get only the date field from all average temperature readings

dates_temp = [item['date'] for item in avg_temps]

# %%
# Get the temperature from all average temperature readings

temps = [item['value'] for item in avg_temps]

# %%
temps
# Out:
# [116,
#  114,
#  14,
#  -27,
#  32,
#  49,
#  7,
#  -25,
#  14,
#  16,
#  -54,
#  -19,
#  40,
#  48,
#  -67,
#  -80,
#  39,
#  18,
#  32,
#  51,
#  -60,
#  -59,
#  -7,
#  -2,
#  36,
#  -23,
#  -42,
#  1,
#  -48,
#  -71,
#  -34,
#  -17,
#  23,
#  64,
#  58,
#  -28,
#  -48,
#  5,
#  41,
#  28,
#  63,
#  86,
#  118,
#  28,
#  -43,
#  -47,
#  16,
#  116,
#  99,
#  1,
#  -26,
#  41,
#  56,
#  144,
#  11,
#  8,
#  -11,
#  24,
#  8,
#  26,
#  77,
#  56,
#  -19,
#  31,
#  96,
#  182,
#  87,
#  32,
#  40,
#  72,
#  51,
#  -23,
#  53,
#  116,
#  136,
#  82,
#  139,
#  131,
#  143,
#  104,
#  107,
#  72,
#  57,
#  96,
#  104,
#  59,
#  -15,
#  -12,
#  26,
#  99,
#  131,
#  72,
#  70,
#  76,
#  97,
#  86,
#  91,
#  128,
#  114,
#  86,
#  88,
#  134,
#  154,
#  163,
#  157,
#  157,
#  83,
#  79,
#  76,
#  94,
#  106,
#  146,
#  133,
#  128,
#  104,
#  115,
#  116,
#  82,
#  104,
#  129,
#  136,
#  121,
#  124,
#  120,
#  172,
#  148,
#  100,
#  104,
#  135,
#  154,
#  161,
#  171,
#  160,
# ...

# %%
# These look suspicious but they are tenths of a degree Celsius so 116 means 11.6'C.

# %%
# Put the results in a dataframe

df_temp = pd.DataFrame()

# %%
# Get only date and cast it to date time; convert temperature from tenths of Celsius to normal Celsius

df_temp['date'] = [datetime.strptime(d, "%Y-%m-%dT%H:%M:%S") for d in dates_temp]
df_temp['avgTemp'] = [float(v)/10.0 for v in temps]

# %%
# Check that the temperatures are now sensible values

df_temp.head()
# Out:
#         date  avgTemp
# 0 2022-01-01     11.6
# 1 2022-01-02     11.4
# 2 2022-01-03      1.4
# 3 2022-01-04     -2.7
# 4 2022-01-05      3.2

# %%
df_temp.tail()
# Out:
#           date  avgTemp
# 360 2022-12-27     -0.7
# 361 2022-12-28      3.4
# 362 2022-12-29      6.4
# 363 2022-12-30      9.3
# 364 2022-12-31      8.2

# %%
# Check types of each column in df

df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
# Convert start and end times to datetime64

df['start_time'] = pd.to_datetime(df['start_time'], dayfirst = True)

df['end_time'] = pd.to_datetime(df['end_time'], dayfirst = True)

# %%
# Create date column in the Y-M-D format to help with the merge

df['date'] = pd.to_datetime(df['start_time'], format='%Y-%m-%d').dt.date

# %%
# Convert date column to datetime64

df['date'] = pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#             ride_id  rideable_type              start_time  \
# 0  9D0DC440CB40CF8E  electric_bike 2022-08-27 13:56:47.728
# 1  2214991DFBE5C4D7  electric_bike 2022-08-20 10:37:02.756
# 2  20C5D469563B6337   classic_bike 2022-08-31 18:55:03.051
# 3  3E8791885BC189D1   classic_bike 2022-08-02 08:05:00.250
# 4  8DBCBF98885106CB  electric_bike 2022-08-25 15:44:48.386
#
#                  end_time        start_station_name start_station_id  \
# 0 2022-08-27 14:02:56.651  Flatbush Ave & Ocean Ave          3704.04
# 1 2022-08-20 10:45:56.631    Forsyth St\t& Grand St          5382.07
# 2 2022-08-31 19:03:37.344    Perry St & Bleecker St          5922.07
# 3 2022-08-02 08:16:52.063       FDR Drive & E 35 St          6230.04
# 4 2022-08-25 15:55:39.691           E 40 St & 5 Ave          6474.11
#
#                     end_station_name end_station_id  start_lat  start_lng  \
# 0          3 St & Prospect Park West        3865.05  40.663657 -73.963014
# ...

# %%
df.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# start_time            datetime64[ns]
# end_time              datetime64[ns]
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# date                  datetime64[ns]
# dtype: object

# %%
# Recheck df_temp

df_temp.head()
# Out:
#         date  avgTemp
# 0 2022-01-01     11.6
# 1 2022-01-02     11.4
# 2 2022-01-03      1.4
# 3 2022-01-04     -2.7
# 4 2022-01-05      3.2

# %%
df_temp.dtypes
# Out:
# date       datetime64[ns]
# avgTemp           float64
# dtype: object

# %%
# Merge can now go ahead using the 'date' column

df_merged = df.merge(df_temp, how = 'left', on = 'date', indicator = True)

# %%
df_merged['_merge'].value_counts()
# Out:
# both          29838166
# left_only          640
# right_only           0
# Name: _merge, dtype: int64

# %%
df_merged.head()
# Out:
#             ride_id  rideable_type              start_time  \
# 0  9D0DC440CB40CF8E  electric_bike 2022-08-27 13:56:47.728
# 1  2214991DFBE5C4D7  electric_bike 2022-08-20 10:37:02.756
# 2  20C5D469563B6337   classic_bike 2022-08-31 18:55:03.051
# 3  3E8791885BC189D1   classic_bike 2022-08-02 08:05:00.250
# 4  8DBCBF98885106CB  electric_bike 2022-08-25 15:44:48.386
#
#                  end_time        start_station_name start_station_id  \
# 0 2022-08-27 14:02:56.651  Flatbush Ave & Ocean Ave          3704.04
# 1 2022-08-20 10:45:56.631    Forsyth St\t& Grand St          5382.07
# 2 2022-08-31 19:03:37.344    Perry St & Bleecker St          5922.07
# 3 2022-08-02 08:16:52.063       FDR Drive & E 35 St          6230.04
# 4 2022-08-25 15:55:39.691           E 40 St & 5 Ave          6474.11
#
#                     end_station_name end_station_id  start_lat  start_lng  \
# 0          3 St & Prospect Park West        3865.05  40.663657 -73.963014
# ...

# %%
# Trying to find out why there are 640 rows that didn't match to a date to receive a temperature

df_temp.shape
# Out:
# (365, 2)

# %%
df_temp['avgTemp'].isnull().value_counts()
# Out:
# False    365
# Name: avgTemp, dtype: int64

# %%
left_only_rows = df_merged[df_merged['_merge'] == 'left_only']
left_only_rows[['start_time', 'date', 'avgTemp']]
# Out:
#                       start_time       date  avgTemp
# 5822796  2021-02-15 14:11:20.946 2021-02-15      NaN
# 8523027  2021-12-31 15:54:01.151 2021-12-31      NaN
# 9866906  2021-11-22 21:28:35.151 2021-11-22      NaN
# 9876393  2021-04-30 16:56:21.003 2021-04-30      NaN
# 10240287 2021-12-12 05:18:01.991 2021-12-12      NaN
# ...                          ...        ...      ...
# 29236803 2021-12-31 23:44:17.183 2021-12-31      NaN
# 29238459 2021-12-31 21:02:06.246 2021-12-31      NaN
# 29240127 2021-12-31 22:46:28.302 2021-12-31      NaN
# 29244462 2021-12-31 23:47:28.230 2021-12-31      NaN
# 29395359 2021-07-16 17:50:59.271 2021-07-16      NaN
#
# [640 rows x 3 columns]

# %%
left_only_rows['date'].value_counts()
# Out:
# 2021-12-31    583
# 2021-12-30      9
# 2021-12-29      4
# 2021-11-13      3
# 2021-12-26      3
# 2021-12-11      3
# 2021-11-17      2
# 2021-12-04      2
# 2021-09-05      2
# 2021-12-12      2
# 2021-12-06      1
# 2021-10-27      1
# 2021-07-22      1
# 2021-11-07      1
# 2021-11-09      1
# 2021-11-16      1
# 2021-12-14      1
# 2021-12-23      1
# 2021-12-28      1
# 2021-09-13      1
# 2021-02-15      1
# 2021-11-18      1
# 2021-01-30      1
# 2021-06-04      1
# 2021-03-11      1
# 2021-03-31      1
# 2021-07-10      1
# 2021-03-14      1
# 2021-07-19      1
# 2021-08-16      1
# 2021-12-08      1
# 2021-12-19      1
# 2021-11-21      1
# 2021-12-02      1
# 2021-04-30      1
# 2021-11-22      1
# 2021-07-16      1
# Name: date, dtype: int64

# %%
# So most of these were rentals that began the day before or a few days before 2022 started.
# I'll deal with these in the cleaning stage when I see what is coming in the next exercise.

# %%
# Export file to csv

df_merged.to_csv(os.path.join(folderpath, 'ny_data.csv'))
