# %% [markdown]
# # Ex 1.2 Project Planning and Sourcing Data using an API

# %% [markdown]
# ### Install and Import Libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os
import requests
import json
from datetime import datetime
